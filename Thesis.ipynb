# %%
from rdflib import *
import numpy as np
import pylab
import os
import matplotlib.pyplot as plt
import matplotlib
import FuXi
from pandas import *
from IPython.lib.pretty import pprint
from tabulate import tabulate

# %%
#Getting RDF datasets 
#Parsing Datasets
g = Graph()
g.parse("http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides.rdf")
print("graph has %s statements." % len(g))
# Out:
# graph has 15687 statements.

# %%
#Getting Police Death Statistics 
#Displaying RDF Model
for s, p, o in g:
   if (s, p, o) not in g:
       raise Exception("It better be!")
#Printing Raw RDF DCAT Data
print( g.serialize(format='n3') )
# Out:
# @prefix : <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides.owl#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix terms: <http://www.socrata.com/rdf/terms#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#hasAge> a owl:FunctionalProperty,
#         owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> ;
#     rdfs:range <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Age> ;
#     rdfs:subPropertyOf owl:topObjectProperty ;
#     owl:inverseOf <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#isAgeOf> .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#hasCauseOfDeath> a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> ;
#     rdfs:range <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Cause> ;
#     owl:inverseOf <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#isCauseOfDeath> .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#hasGender> a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> ;
#     rdfs:range <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Gender> ;
#     owl:inverseOf <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#isGenderOf> .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#isAgency> a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Agency> ;
#     rdfs:range <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> ;
#     owl:inverseOf <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#hasHomicideByAgency> .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#isRaceOf> a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Race> ;
#     rdfs:range <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> ;
#     owl:inverseOf <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#hasRace> .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#isStateOf> a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:domain :State ;
#     rdfs:range <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> ;
#     owl:inverseOf <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#livedInState> .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides.owl> a owl:Ontology ;
#     rdfs:comment "Homicides by Police"^^xsd:string ;
#     owl:versionIRI <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides.owl/1.1> .
#
# :address a owl:AnnotationProperty,
#         owl:DatatypeProperty ;
#     rdfs:domain :Address ;
#     rdfs:range xsd:string .
#
# :age a owl:AnnotationProperty,
#         owl:DatatypeProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Age> ;
#     rdfs:range xsd:integer .
#
# :agency a owl:AnnotationProperty,
#         owl:DatatypeProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Agency> ;
#     rdfs:range xsd:string .
#
# :armed a owl:AnnotationProperty,
#         owl:DatatypeProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Armed> ;
#     rdfs:range xsd:string .
#
# :cause a owl:AnnotationProperty,
#         owl:DatatypeProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Cause> ;
#     rdfs:range xsd:string ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :city a owl:AnnotationProperty,
#         owl:DatatypeProperty ;
#     rdfs:domain :City ;
#     rdfs:range xsd:string .
#
# :day a owl:AnnotationProperty,
#         owl:DatatypeProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Day> ;
#     rdfs:range xsd:integer .
#
# :gender a owl:AnnotationProperty,
#         owl:DatatypeProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Gender> ;
#     rdfs:range xsd:string .
#
# :isCityOf a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:domain :City ;
#     rdfs:range <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> ;
#     owl:inverseOf :livedInCity .
#
# :month a owl:AnnotationProperty,
#         owl:DatatypeProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Month> ;
#     rdfs:range xsd:string .
#
# :name a owl:AnnotationProperty,
#         owl:DatatypeProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Name> ;
#     rdfs:range xsd:string ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# :race a owl:AnnotationProperty,
#         owl:DatatypeProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Race> ;
#     rdfs:range xsd:string .
#
# :state a owl:AnnotationProperty,
#         owl:DatatypeProperty ;
#     rdfs:domain :State ;
#     rdfs:range xsd:string .
#
# :wasAddressOf a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:domain :Address ;
#     rdfs:range <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> ;
#     owl:inverseOf :hadAddress .
#
# :year a owl:AnnotationProperty,
#         owl:DatatypeProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Year> ;
#     rdfs:range xsd:int ;
#     rdfs:subPropertyOf owl:topDataProperty .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/1> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1050 Carl Griffin Dr" ;
#     :age "22" ;
#     :agency "Chatham County Sheriff's Office" ;
#     :armed "No" ;
#     :cause "Death in custody" ;
#     :city "Savannah" ;
#     :day "1" ;
#     :gender "Male" ;
#     :month "January" ;
#     :name "Matthew Ajibade" ;
#     :race "Black" ;
#     :state "GA" ;
#     :year "2015" ;
#     terms:rowID "1" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/10> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1618 E 123rd St" ;
#     :age "26" ;
#     :agency "Los Angeles County Sheriff's Department" ;
#     :armed "No" ;
#     :cause "Taser" ;
#     :city "Los Angeles" ;
#     :day "6" ;
#     :gender "Male" ;
#     :month "January" ;
#     :name "Brian Pickett" ;
#     :race "Black" ;
#     :state "CA" ;
#     :year "2015" ;
#     terms:rowID "10" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/100> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "2400 W Tharpe St" ;
#     :age "28" ;
#     :agency "Tallahassee Police Department" ;
#     :armed "No" ;
#     :cause "Gunshot" ;
#     :city "Tallahassee" ;
#     :day "5" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Jeremy Lett" ;
#     :race "Black" ;
#     :state "FL" ;
#     :year "2015" ;
#     terms:rowID "100" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/101> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "US-287" ;
#     :age "35" ;
#     :agency "Wichita County Sheriff's Office" ;
#     :armed "No" ;
#     :cause "Taser" ;
#     :city "Electra" ;
#     :day "5" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Wilber Castillo-Gongora" ;
#     :race "Hispanic/Latino" ;
#     :state "TX" ;
#     :year "2015" ;
#     terms:rowID "101" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/102> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1200 Calimesa Blvd" ;
#     :age "35" ;
#     :agency "Riverside County Sheriff's Department" ;
#     :armed "Non-lethal firearm" ;
#     :cause "Gunshot" ;
#     :city "Calimesa" ;
#     :day "5" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "John Sawyer" ;
#     :race "White" ;
#     :state "CA" ;
#     :year "2015" ;
#     terms:rowID "102" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/103> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1000 SW 62nd St" ;
#     :age "26" ;
#     :agency "Oklahoma City Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Oklahoma City" ;
#     :day "6" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Herbert Hill" ;
#     :race "Black" ;
#     :state "OK" ;
#     :year "2015" ;
#     terms:rowID "103" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/104> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "200 Abbie St SE" ;
#     :age "31" ;
#     :agency "Kentwood Police Department and Wyoming DPS" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Wyoming" ;
#     :day "7" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Alan James" ;
#     :race "White" ;
#     :state "MI" ;
#     :year "2015" ;
#     terms:rowID "104" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/105> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "2704 Mary Ave" ;
#     :age "74" ;
#     :agency "Gastonia Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Gastonia" ;
#     :day "7" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "James Allen" ;
#     :race "Black" ;
#     :state "NC" ;
#     :year "2015" ;
#     terms:rowID "105" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/106> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "Texas Hwy 71 and Silvermine Dr" ;
#     :age "27" ;
#     :agency "Austin Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Austin" ;
#     :day "8" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Sawyer Flache" ;
#     :race "White" ;
#     :state "TX" ;
#     :year "2015" ;
#     terms:rowID "106" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/107> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "Fairfax County Adult Detention Center, 10520 Judicial Dr" ;
#     :age "37" ;
#     :agency "Fairfax County Sheriff's Office" ;
#     :armed "No" ;
#     :cause "Taser" ;
#     :city "Fairfax" ;
#     :day "3" ;
#     :gender "Female" ;
#     :month "February" ;
#     :name "Natasha McKenna" ;
#     :race "Black" ;
#     :state "VA" ;
#     :year "2015" ;
#     terms:rowID "107" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/108> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "Conway Rd and Hoffner Ave" ;
#     :age "46" ;
#     :agency "Orange County Sheriff's Office" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Orlando" ;
#     :day "8" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Joseph Paffen" ;
#     :race "White" ;
#     :state "FL" ;
#     :year "2015" ;
#     terms:rowID "108" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/109> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "200 Jordan Dr" ;
#     :age "41" ;
#     :agency "Nocona Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Nocona" ;
#     :day "9" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Larry Hostetter" ;
#     :race "White" ;
#     :state "TX" ;
#     :year "2015" ;
#     terms:rowID "109" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/11> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "104 N Garfield Ave" ;
#     :age "34" ;
#     :agency "Burlington Police Department" ;
#     :armed "No" ;
#     :cause "Gunshot" ;
#     :city "Burlington" ;
#     :day "6" ;
#     :gender "Female" ;
#     :month "January" ;
#     :name "Autumn Steele" ;
#     :race "White" ;
#     :state "IA" ;
#     :year "2015" ;
#     terms:rowID "11" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/110> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "7400 Bonnie View Rd" ;
#     :age "45" ;
#     :agency "Dallas Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Dallas" ;
#     :day "9" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Desmond Luster" ;
#     :race "Black" ;
#     :state "TX" ;
#     :year "2015" ;
#     terms:rowID "110" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/111> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "N Little Tor Rd" ;
#     :age "57" ;
#     :agency "Clarkstown Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "New City" ;
#     :day "9" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Vincent Cordaro" ;
#     :race "White" ;
#     :state "NY" ;
#     :year "2015" ;
#     terms:rowID "111" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/112> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "13600 Culver Blvd" ;
#     :age "64" ;
#     :agency "Los Angeles Police Department" ;
#     :armed "No" ;
#     :cause "Struck by vehicle" ;
#     :city "Los Angeles" ;
#     :day "9" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Dean Bucheit" ;
#     :race "White" ;
#     :state "CA" ;
#     :year "2015" ;
#     terms:rowID "112" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/113> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1503 Medfra St" ;
#     :age "33" ;
#     :agency "Anchorage Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Anchorage" ;
#     :day "10" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "John Whittaker" ;
#     :race "Hispanic/Latino" ;
#     :state "AK" ;
#     :year "2015" ;
#     terms:rowID "113" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/114> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1107 W Lewis St" ;
#     :age "35" ;
#     :agency "Pasco Police Department" ;
#     :armed "Other" ;
#     :cause "Gunshot" ;
#     :city "Pasco" ;
#     :day "10" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Antonio Zambrano-Montes" ;
#     :race "Hispanic/Latino" ;
#     :state "WA" ;
#     :year "2015" ;
#     terms:rowID "114" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/115> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "I-70 and US-6" ;
#     :age "45" ;
#     :agency "Garfield County Sheriff's Office" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Glenwood Springs" ;
#     :day "10" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Brian Fritze" ;
#     :race "White" ;
#     :state "CO" ;
#     :year "2015" ;
#     terms:rowID "115" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/116> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "4545 Aldridge Dr" ;
#     :age "48" ;
#     :agency "Memphis Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Memphis" ;
#     :day "10" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Anthony Bess" ;
#     :race "Black" ;
#     :state "TN" ;
#     :year "2015" ;
#     terms:rowID "116" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/117> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "645 Smyrna Center Rd" ;
#     :age "61" ;
#     :agency "Maine State Troopers and Aroostook County Sheriff's Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Smyrna" ;
#     :day "10" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Kenneth Kreyssig" ;
#     :race "White" ;
#     :state "ME" ;
#     :year "2015" ;
#     terms:rowID "117" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/118> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1300 Sherman St" ;
#     :age "23" ;
#     :agency "San Jose Police Department" ;
#     :armed "Knife" ;
#     :cause "Gunshot" ;
#     :city "San Jose" ;
#     :day "11" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Phillip Watkins" ;
#     :race "Black" ;
#     :state "CA" ;
#     :year "2015" ;
#     terms:rowID "118" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/119> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1790 Booger Hollow Rd" ;
#     :age "46" ;
#     :agency "Tallapoosa County Sheriff's Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Dadeville" ;
#     :day "11" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Fletcher Stewart" ;
#     :race "White" ;
#     :state "AL" ;
#     :year "2015" ;
#     terms:rowID "119" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/12> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "2388 E Kansas Hwy 4" ;
#     :age "35" ;
#     :agency "Saline County Sheriff's Office" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Assaria" ;
#     :day "6" ;
#     :gender "Male" ;
#     :month "January" ;
#     :name "Brock Nichols" ;
#     :race "White" ;
#     :state "KS" ;
#     :year "2015" ;
#     terms:rowID "12" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/120> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "S 12th St and Ruby St" ;
#     :age "21" ;
#     :agency "Kansas City KS Police Department and Kansas Highway Patrol" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Kansas City" ;
#     :day "13" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Andres Lara-Rodriguez" ;
#     :race "Hispanic/Latino" ;
#     :state "KS" ;
#     :year "2015" ;
#     terms:rowID "120" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/121> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "4023 University Pkwy" ;
#     :age "23" ;
#     :agency "San Bernardino Police Department" ;
#     :armed "Vehicle" ;
#     :cause "Gunshot" ;
#     :city "San Bernadino" ;
#     :day "13" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Jonathan Harden" ;
#     :race "White" ;
#     :state "CA" ;
#     :year "2015" ;
#     terms:rowID "121" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/122> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "2420 Terry Rd" ;
#     :age "27" ;
#     :agency "Carroll County Sheriff's Office" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Huntingdon" ;
#     :day "13" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Matthew Belk" ;
#     :race "White" ;
#     :state "TN" ;
#     :year "2015" ;
#     terms:rowID "122" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/123> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "414 Rehr St" ;
#     :age "35" ;
#     :agency "Pennsylvania State Police" ;
#     :armed "Unknown" ;
#     :cause "Gunshot" ;
#     :city "Reading" ;
#     :day "13" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Richard Carlin" ;
#     :race "White" ;
#     :state "PA" ;
#     :year "2015" ;
#     terms:rowID "123" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/124> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "Gale St" ;
#     :age "51" ;
#     :agency "Laredo Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Laredo" ;
#     :day "14" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Roy Day" ;
#     :race "White" ;
#     :state "TX" ;
#     :year "2015" ;
#     terms:rowID "124" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/125> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1600 W 500 N" ;
#     :age "24" ;
#     :agency "Provo Police Department" ;
#     :armed "Non-lethal firearm" ;
#     :cause "Gunshot" ;
#     :city "Provo" ;
#     :day "15" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Cody Evans" ;
#     :race "White" ;
#     :state "UT" ;
#     :year "2015" ;
#     terms:rowID "125" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/126> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "19157 NW 3rd Ave" ;
#     :age "25" ;
#     :agency "Miami Gardens Police Department" ;
#     :armed "Other" ;
#     :cause "Gunshot" ;
#     :city "Miami Gardens" ;
#     :day "15" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Lavall Hall" ;
#     :race "Black" ;
#     :state "FL" ;
#     :year "2015" ;
#     terms:rowID "126" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/127> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "29000 S Wall St" ;
#     :age "34" ;
#     :agency "Clackamas County Sheriff's Office" ;
#     :armed "Knife" ;
#     :cause "Gunshot" ;
#     :city "Colton" ;
#     :day "15" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Bruce Steward" ;
#     :race "White" ;
#     :state "OR" ;
#     :year "2015" ;
#     terms:rowID "127" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/128> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1110 Battleground Dr" ;
#     :age "34" ;
#     :agency "Iuka Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Iuka" ;
#     :day "15" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Howard Brent Means Jr" ;
#     :race "White" ;
#     :state "MS" ;
#     :year "2015" ;
#     terms:rowID "128" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/129> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "200 S McNab Pkwy" ;
#     :age "37" ;
#     :agency "Pinal County Sheriff's Office" ;
#     :armed "Knife" ;
#     :cause "Gunshot" ;
#     :city "San Manuel" ;
#     :day "15" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Daniel Mejia" ;
#     :race "Hispanic/Latino" ;
#     :state "AZ" ;
#     :year "2015" ;
#     terms:rowID "129" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/13> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "Redlyn St" ;
#     :age "47" ;
#     :agency "US Marshals Service, Pennsylvania State Police, Allegheny County Sheriff's Office" ;
#     :armed "Non-lethal firearm" ;
#     :cause "Gunshot" ;
#     :city "Pittsburgh" ;
#     :day "6" ;
#     :gender "Male" ;
#     :month "January" ;
#     :name "Leslie Sapp III" ;
#     :race "Black" ;
#     :state "PA" ;
#     :year "2015" ;
#     terms:rowID "13" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/130> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1600 3rd St" ;
#     :age "17" ;
#     :agency "Bay City Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Bay City" ;
#     :day "2" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Jacob Haglund" ;
#     :race "White" ;
#     :state "MI" ;
#     :year "2015" ;
#     terms:rowID "130" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/131> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "Malad St and Gourley St" ;
#     :age "26" ;
#     :agency "Boise Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Boise" ;
#     :day "16" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Michael Casper" ;
#     :race "White" ;
#     :state "ID" ;
#     :year "2015" ;
#     terms:rowID "131" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/132> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "8351 N Cracker Barrel Rd" ;
#     :age "56" ;
#     :agency "Marana Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Marana" ;
#     :day "16" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Daniel Caldwell" ;
#     :race "White" ;
#     :state "AZ" ;
#     :year "2015" ;
#     terms:rowID "132" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/133> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "Forest Ave" ;
#     :age "30" ;
#     :agency "Tewksbury Police Department" ;
#     :armed "Non-lethal firearm" ;
#     :cause "Gunshot" ;
#     :city "Tewksbury" ;
#     :day "17" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Doug Sparks" ;
#     :race "White" ;
#     :state "MA" ;
#     :year "2015" ;
#     terms:rowID "133" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/134> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "3600 Canfield Rd" ;
#     :age "32" ;
#     :agency "Eaton County Sheriff's Office" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Eaton Rapids Township" ;
#     :day "17" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Matthew Lundy" ;
#     :race "White" ;
#     :state "MI" ;
#     :year "2015" ;
#     terms:rowID "134" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/135> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "2325 Union Rd" ;
#     :age "43" ;
#     :agency "Gastonia Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Gastonia" ;
#     :day "17" ;
#     :gender "Female" ;
#     :month "February" ;
#     :name "Betty Sexton" ;
#     :race "White" ;
#     :state "NC" ;
#     :year "2015" ;
#     terms:rowID "135" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/136> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "US-90 and Charles Dr" ;
#     :age "50" ;
#     :agency "Del Rio Police Department and Val Verde County Sheriff's Office" ;
#     :armed "Other" ;
#     :cause "Gunshot" ;
#     :city "Del Rio" ;
#     :day "17" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Pedro 'Pete' Juan Saldivar" ;
#     :race "Hispanic/Latino" ;
#     :state "TX" ;
#     :year "2015" ;
#     terms:rowID "136" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/137> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1400 N Marion Ave" ;
#     :age "31" ;
#     :agency "Springfield Police Department" ;
#     :armed "No" ;
#     :cause "Gunshot" ;
#     :city "Springfield" ;
#     :day "17" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Michael Ireland" ;
#     :race "White" ;
#     :state "MO" ;
#     :year "2015" ;
#     terms:rowID "137" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/138> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "Bellefonte Dr" ;
#     :age "20" ;
#     :agency "Charlotte-Mecklenburg Police Department" ;
#     :armed "Knife" ;
#     :cause "Gunshot" ;
#     :city "Charlotte" ;
#     :day "19" ;
#     :gender "Female" ;
#     :month "February" ;
#     :name "Janisha Fonville" ;
#     :race "Black" ;
#     :state "NC" ;
#     :year "2015" ;
#     terms:rowID "138" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/139> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "Hammonton Smartville Rd" ;
#     :age "35" ;
#     :agency "Yuba County Sheriff's Office" ;
#     :armed "No" ;
#     :cause "Taser" ;
#     :city "Marysville" ;
#     :day "15" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Chance Thompson" ;
#     :race "White" ;
#     :state "CA" ;
#     :year "2015" ;
#     terms:rowID "139" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/14> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "SE 4th St and Scott Ave" ;
#     :age "30" ;
#     :agency "Des Moines Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Des Moines" ;
#     :day "7" ;
#     :gender "Male" ;
#     :month "January" ;
#     :name "Nicholas Brickman" ;
#     :race "White" ;
#     :state "IA" ;
#     :year "2015" ;
#     terms:rowID "14" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/140> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "2500 Texas Hwy 121" ;
#     :age "31" ;
#     :agency "Grapevine Police Department" ;
#     :armed "No" ;
#     :cause "Gunshot" ;
#     :city "Euless" ;
#     :day "20" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Rubén García Villalpando" ;
#     :race "Hispanic/Latino" ;
#     :state "TX" ;
#     :year "2015" ;
#     terms:rowID "140" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/141> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "2200 Green Springs Hwy" ;
#     :age "38" ;
#     :agency "Homewood Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Birmingham" ;
#     :day "20" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Stanley Grant" ;
#     :race "Black" ;
#     :state "AL" ;
#     :year "2015" ;
#     terms:rowID "141" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/142> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1200 E Airtex Dr" ;
#     :agency "US Marshals Service, Texas Department of Criminal Justice" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Houston" ;
#     :day "20" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Alejandro Salazar" ;
#     :race "Hispanic/Latino" ;
#     :state "TX" ;
#     :year "2015" ;
#     terms:rowID "142" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/143> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "298 Gavilan Canyon Rd" ;
#     :age "41" ;
#     :agency "New Mexico State Police and US Marshals Service" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Rudioso" ;
#     :day "21" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Jason Carter" ;
#     :race "White" ;
#     :state "NM" ;
#     :year "2015" ;
#     terms:rowID "143" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/144> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "951 West 36th St N" ;
#     :age "41" ;
#     :agency "Osage Nation Police Department, Osage County Sheriff's Office" ;
#     :armed "No" ;
#     :cause "Taser" ;
#     :city "Tulsa" ;
#     :day "21" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Terry Price" ;
#     :race "Black" ;
#     :state "OK" ;
#     :year "2015" ;
#     terms:rowID "144" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/145> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1800 Heather Cir" ;
#     :age "51" ;
#     :agency "Indianapolis Metropolitan Police Department" ;
#     :armed "Knife" ;
#     :cause "Gunshot" ;
#     :city "Indianapolis" ;
#     :day "21" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Kent Norman" ;
#     :race "White" ;
#     :state "IN" ;
#     :year "2015" ;
#     terms:rowID "145" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/146> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "Lower Pond Ct" ;
#     :age "41" ;
#     :agency "Habersham County Sheriff's Office" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Clarkesville" ;
#     :day "22" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Anthony Giaquinta" ;
#     :race "Hispanic/Latino" ;
#     :state "GA" ;
#     :year "2015" ;
#     terms:rowID "146" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/147> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "900 Castile Rd SE" ;
#     :age "50" ;
#     :agency "Palm Bay Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Palm Bay" ;
#     :day "22" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Bradford Leonard" ;
#     :race "White" ;
#     :state "FL" ;
#     :year "2015" ;
#     terms:rowID "147" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/148> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "Clearview Ln" ;
#     :age "16" ;
#     :agency "Millbrook Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Millbrook" ;
#     :day "23" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "A'donte Washington" ;
#     :race "Black" ;
#     :state "AL" ;
#     :year "2015" ;
#     terms:rowID "148" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/149> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "4817 W Mceachern Woods Dr" ;
#     :age "37" ;
#     :agency "Cobb County Sheriff's Office" ;
#     :armed "Knife" ;
#     :cause "Gunshot" ;
#     :city "Powder Springs" ;
#     :day "23" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Michael Smashey" ;
#     :race "White" ;
#     :state "GA" ;
#     :year "2015" ;
#     terms:rowID "149" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/15> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "6300 Scott St" ;
#     :age "31" ;
#     :agency "Rosemont Police Department" ;
#     :armed "Vehicle" ;
#     :cause "Gunshot" ;
#     :city "Rosemont" ;
#     :day "7" ;
#     :gender "Male" ;
#     :month "January" ;
#     :name "Joseph Caffarello" ;
#     :race "White" ;
#     :state "IL" ;
#     :year "2015" ;
#     terms:rowID "15" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/150> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1300 N Plymouth St" ;
#     :age "42" ;
#     :agency "Catasauqua Police Department" ;
#     :armed "Knife" ;
#     :cause "Gunshot" ;
#     :city "Allentown" ;
#     :day "23" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Jerome Nichols" ;
#     :race "White" ;
#     :state "PA" ;
#     :year "2015" ;
#     terms:rowID "150" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/151> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "175 Bass Pro Blvd" ;
#     :age "47" ;
#     :agency "Denham Springs Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Denham Springs" ;
#     :day "23" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Robert Kohl" ;
#     :race "White" ;
#     :state "LA" ;
#     :year "2015" ;
#     terms:rowID "151" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/152> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1511 Plymouth Ln" ;
#     :age "30" ;
#     :agency "Green Bay Police Department" ;
#     :armed "Knife" ;
#     :cause "Gunshot" ;
#     :city "Green Bay" ;
#     :day "24" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Joseph Biegert" ;
#     :race "White" ;
#     :state "WI" ;
#     :year "2015" ;
#     terms:rowID "152" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/153> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1299 Hickory St" ;
#     :age "39" ;
#     :agency "Omaha Police Department" ;
#     :armed "No" ;
#     :cause "Gunshot" ;
#     :city "Omaha" ;
#     :day "24" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Daniel Elrod" ;
#     :race "White" ;
#     :state "NE" ;
#     :year "2015" ;
#     terms:rowID "153" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/154> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "25th St and Poplar St" ;
#     :age "31" ;
#     :agency "Terre Haute Police Department" ;
#     :armed "No" ;
#     :cause "Gunshot" ;
#     :city "Terre Haute" ;
#     :day "25" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Alexander Long" ;
#     :race "White" ;
#     :state "IN" ;
#     :year "2015" ;
#     terms:rowID "154" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/155> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "2201 NW 27th St" ;
#     :age "37" ;
#     :agency "Oklahoma City Police Department" ;
#     :armed "Vehicle" ;
#     :cause "Gunshot" ;
#     :city "Oklahoma City" ;
#     :day "25" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Glenn Lewis" ;
#     :race "Black" ;
#     :state "OK" ;
#     :year "2015" ;
#     terms:rowID "155" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/156> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "5300 East Craig Road" ;
#     :age "43" ;
#     :agency "Las Vegas Metro Police (Swat)" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Las Vegas" ;
#     :day "25" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Francis Spivey" ;
#     :race "White" ;
#     :state "NV" ;
#     :year "2015" ;
#     terms:rowID "156" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/157> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "Folsom St and 24th St" ;
#     :age "21" ;
#     :agency "San Francisco Police Department" ;
#     :armed "Knife" ;
#     :cause "Gunshot" ;
#     :city "San Francisco" ;
#     :day "26" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Amilcar Perez-Lopez" ;
#     :race "Hispanic/Latino" ;
#     :state "CA" ;
#     :year "2015" ;
#     terms:rowID "157" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/158> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "5101 Georgia Rte 133" ;
#     :age "34" ;
#     :agency "Worth County Sheriff's Office" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Moultrie" ;
#     :day "26" ;
#     :gender "Female" ;
#     :month "February" ;
#     :name "Crystal Miley" ;
#     :race "White" ;
#     :state "GA" ;
#     :year "2015" ;
#     terms:rowID "158" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/159> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "4660 N Socrum Loop Rd" ;
#     :age "42" ;
#     :agency "Lakeland Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Lakeland" ;
#     :day "26" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "David Cuevas" ;
#     :race "Hispanic/Latino" ;
#     :state "FL" ;
#     :year "2015" ;
#     terms:rowID "159" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/16> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "310 Yaupon St" ;
#     :age "32" ;
#     :agency "Freeport Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Freeport" ;
#     :day "7" ;
#     :gender "Male" ;
#     :month "January" ;
#     :name "Ronald Sneed" ;
#     :race "Black" ;
#     :state "TX" ;
#     :year "2015" ;
#     terms:rowID "16" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/160> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "US-49 and Middle Driveway" ;
#     :age "49" ;
#     :agency "Gulfport Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Gulfport" ;
#     :day "26" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Rodney Biggs" ;
#     :race "White" ;
#     :state "MS" ;
#     :year "2015" ;
#     terms:rowID "160" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/161> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "South Carolina Rte 8 and Augusta Rd" ;
#     :age "24" ;
#     :agency "Greenville County Sheriff's Office" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Peltzer" ;
#     :day "27" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Chazsten Freeman" ;
#     :race "White" ;
#     :state "SC" ;
#     :year "2015" ;
#     terms:rowID "161" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/162> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1000 W 3rd St" ;
#     :age "27" ;
#     :agency "Santa Ana Police Department" ;
#     :armed "No" ;
#     :cause "Gunshot" ;
#     :city "Santa Ana" ;
#     :day "27" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Ernesto Javier Canepa Diaz" ;
#     :race "Hispanic/Latino" ;
#     :state "CA" ;
#     :year "2015" ;
#     terms:rowID "162" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/163> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1016 N 4th Ave" ;
#     :age "54" ;
#     :agency "Franklin County Corrections Division" ;
#     :armed "No" ;
#     :cause "Death in custody" ;
#     :city "Pasco" ;
#     :day "27" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Russell Sharrer" ;
#     :race "White" ;
#     :state "WA" ;
#     :year "2015" ;
#     terms:rowID "163" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/164> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "E Broadway and US-63" ;
#     :age "28" ;
#     :agency "Boone County Sheriff's Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Columbia" ;
#     :day "28" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Cornelius Parker" ;
#     :race "Black" ;
#     :state "MO" ;
#     :year "2015" ;
#     terms:rowID "164" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/165> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "I-10" ;
#     :age "37" ;
#     :agency "Riverside County Sheriff's Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "La Paz County" ;
#     :day "28" ;
#     :gender "Female" ;
#     :month "February" ;
#     :name "Stephanie Hill" ;
#     :race "White" ;
#     :state "AZ" ;
#     :year "2015" ;
#     terms:rowID "165" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/166> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "2311 Main St" ;
#     :age "40" ;
#     :agency "Tarboro Police Department and Edgecombe Sheriff's Office" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Tarboro" ;
#     :day "28" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Ian Sherrod" ;
#     :race "Black" ;
#     :state "NC" ;
#     :year "2015" ;
#     terms:rowID "166" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/167> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "331 W Grand Ledge Hwy" ;
#     :age "17" ;
#     :agency "Eaton County Sheriff's Office" ;
#     :armed "No" ;
#     :cause "Gunshot" ;
#     :city "Roxand Township" ;
#     :day "28" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Deven Guilford" ;
#     :race "White" ;
#     :state "MI" ;
#     :year "2015" ;
#     terms:rowID "167" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/168> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1113 W St Mary's Rd" ;
#     :age "28" ;
#     :agency "Tucson Police Department" ;
#     :armed "Knife" ;
#     :cause "Gunshot" ;
#     :city "Tuscon" ;
#     :day "28" ;
#     :gender "Female" ;
#     :month "February" ;
#     :name "Jessica Uribe" ;
#     :race "Unknown" ;
#     :state "AZ" ;
#     :year "2015" ;
#     terms:rowID "168" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/169> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "Morton Ave and Chatham Ave" ;
#     :age "34" ;
#     :agency "Wellston Police Department" ;
#     :armed "No" ;
#     :cause "Gunshot" ;
#     :city "St Louis" ;
#     :day "1" ;
#     :gender "Male" ;
#     :month "March" ;
#     :name "Thomas Allen Jr" ;
#     :race "Black" ;
#     :state "MO" ;
#     :year "2015" ;
#     terms:rowID "169" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/17> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "Lasalle St and Josephine St" ;
#     :age "37" ;
#     :agency "New Orleans Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "New Orleans" ;
#     :day "8" ;
#     :gender "Male" ;
#     :month "January" ;
#     :name "Omarr Jackson" ;
#     :race "Black" ;
#     :state "LA" ;
#     :year "2015" ;
#     terms:rowID "17" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/170> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "500 San Pedro St" ;
#     :age "43" ;
#     :agency "Los Angeles Police Department" ;
#     :armed "No" ;
#     :cause "Gunshot" ;
#     :city "Los Angeles" ;
#     :day "1" ;
#     :gender "Male" ;
#     :month "March" ;
#     :name "Charly 'Africa' Keunang" ;
#     :race "Black" ;
#     :state "CA" ;
#     :year "2015" ;
#     terms:rowID "170" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/171> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "620 SW 59th St" ;
#     :age "47" ;
#     :agency "Oklahoma City Police Department" ;
#     :armed "No" ;
#     :cause "Taser" ;
#     :city "Oklahoma City" ;
#     :day "1" ;
#     :gender "Male" ;
#     :month "March" ;
#     :name "Darrell 'Hubbard' Gatewood" ;
#     :race "Black" ;
#     :state "OK" ;
#     :year "2015" ;
#     terms:rowID "171" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/172> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "Mt Pleasant Rd" ;
#     :age "49" ;
#     :agency "George County Sheriff's Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Lucedale" ;
#     :day "1" ;
#     :gender "Male" ;
#     :month "March" ;
#     :name "Donald Matkins" ;
#     :race "White" ;
#     :state "MS" ;
#     :year "2015" ;
#     terms:rowID "172" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/173> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "Waikoloa Rd" ;
#     :age "63" ;
#     :agency "South Kohala Police Department" ;
#     :armed "No" ;
#     :cause "Struck by vehicle" ;
#     :city "Waikoloa Village" ;
#     :day "1" ;
#     :gender "Male" ;
#     :month "March" ;
#     :name "Jeffrey Surnow" ;
#     :race "White" ;
#     :state "HI" ;
#     :year "2015" ;
#     terms:rowID "173" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/174> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1st Ave and Richards St" ;
#     :age "20" ;
#     :agency "Joliet Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Joliet" ;
#     :day "2" ;
#     :gender "Male" ;
#     :month "March" ;
#     :name "Shaquille Barrow" ;
#     :race "Black" ;
#     :state "IL" ;
#     :year "2015" ;
#     terms:rowID "174" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/175> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "700 Dennis St" ;
#     :age "25" ;
#     :agency "Maryland State Police" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Salisbury" ;
#     :day "3" ;
#     :gender "Male" ;
#     :month "March" ;
#     :name "Fednel Rhinvil" ;
#     :race "Black" ;
#     :state "MD" ;
#     :year "2015" ;
#     terms:rowID "175" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/176> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "N College Ave and E Weber Dr" ;
#     :age "25" ;
#     :agency "Tempe Police Department" ;
#     :armed "Knife" ;
#     :cause "Gunshot" ;
#     :city "Tempe" ;
#     :day "3" ;
#     :gender "Male" ;
#     :month "March" ;
#     :name "Matthew Metz" ;
#     :race "White" ;
#     :state "AZ" ;
#     :year "2015" ;
#     terms:rowID "176" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/177> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "831 Maybrook Dr" ;
#     :age "26" ;
#     :agency "Volusia County Sheriff's Office" ;
#     :armed "No" ;
#     :cause "Gunshot" ;
#     :city "Deltona" ;
#     :day "4" ;
#     :gender "Male" ;
#     :month "March" ;
#     :name "Derek Cruice" ;
#     :race "White" ;
#     :state "FL" ;
#     :year "2015" ;
#     terms:rowID "177" .
#
# ...
#     :address "13000 Veterans Memorial Dr" ;
#     :agency "Houston Police Department" ;
#     :armed "Unknown" ;
#     :cause "Gunshot" ;
#     :city "Houston" ;
#     :day "30" ;
#     :gender "Male" ;
#     :month "October" ;
#     :name "Unknown" ;
#     :race "Unknown" ;
#     :state "TX" ;
#     :year "2015" ;
#     terms:rowID "952" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/953> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "I-5" ;
#     :age "36" ;
#     :agency "Oregon State Police" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Salem" ;
#     :day "28" ;
#     :gender "Male" ;
#     :month "October" ;
#     :name "Jasper Adams" ;
#     :race "White" ;
#     :state "OR" ;
#     :year "2015" ;
#     terms:rowID "953" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/954> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "22279 N Four Mile Rd" ;
#     :agency "Cherokee County Sheriff's Office" ;
#     :armed "Knife" ;
#     :cause "Gunshot" ;
#     :city "Fort Gibson" ;
#     :day "30" ;
#     :gender "Male" ;
#     :month "October" ;
#     :name "Unknown" ;
#     :race "Unknown" ;
#     :state "OK" ;
#     :year "2015" ;
#     terms:rowID "954" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/955> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "688 NE 368th Ave" ;
#     :age "52" ;
#     :agency "Dixie County Sheriff's Office" ;
#     :armed "Unknown" ;
#     :cause "Gunshot" ;
#     :city "Old Town" ;
#     :day "29" ;
#     :gender "Male" ;
#     :month "October" ;
#     :name "Larry Busby" ;
#     :race "Unknown" ;
#     :state "FL" ;
#     :year "2015" ;
#     terms:rowID "955" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/956> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "E Platte Ave" ;
#     :age "33" ;
#     :agency "Colorado Springs Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Colorado Springs" ;
#     :day "31" ;
#     :gender "Male" ;
#     :month "October" ;
#     :name "Noah Harpham" ;
#     :race "White" ;
#     :state "CO" ;
#     :year "2015" ;
#     terms:rowID "956" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/957> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "400 Comanchee Dr" ;
#     :age "56" ;
#     :agency "Opelika Police Department" ;
#     :armed "Unknown" ;
#     :cause "Gunshot" ;
#     :city "Opelika" ;
#     :day "31" ;
#     :gender "Male" ;
#     :month "October" ;
#     :name "Bennie Lee Tignor" ;
#     :race "Unknown" ;
#     :state "AL" ;
#     :year "2015" ;
#     terms:rowID "957" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/958> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "500 Harmony Ln SW" ;
#     :age "49" ;
#     :agency "Hutchinson Police Department, McLeod County Sheriff's Office, Minnesota State Patrol" ;
#     :armed "Unknown" ;
#     :cause "Gunshot" ;
#     :city "Hutchinson" ;
#     :day "1" ;
#     :gender "Male" ;
#     :month "November" ;
#     :name "Luverne Christensen" ;
#     :race "Unknown" ;
#     :state "MN" ;
#     :year "2015" ;
#     terms:rowID "958" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/959> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "4th Street and Q Street" ;
#     :agency "California Highway Patrol" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Eureka" ;
#     :day "1" ;
#     :gender "Male" ;
#     :month "November" ;
#     :name "Unknown" ;
#     :race "Unknown" ;
#     :state "CA" ;
#     :year "2015" ;
#     terms:rowID "959" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/96> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "3800 Vernon Ave" ;
#     :age "36" ;
#     :agency "Shelby County Sheriff's Department [US Marshals Service Task Force]" ;
#     :armed "Knife" ;
#     :cause "Gunshot" ;
#     :city "Memphis" ;
#     :day "4" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Markell Atkins" ;
#     :race "Black" ;
#     :state "TN" ;
#     :year "2015" ;
#     terms:rowID "96" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/960> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "US-95" ;
#     :age "62" ;
#     :agency "Adams County Sheriff's Office" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Council" ;
#     :day "1" ;
#     :gender "Male" ;
#     :month "November" ;
#     :name "Jack Yantis" ;
#     :race "Unknown" ;
#     :state "ID" ;
#     :year "2015" ;
#     terms:rowID "960" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/961> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "2800 Gainesville St SE" ;
#     :age "62" ;
#     :agency "Prince George's County Police Department, Forest Heights Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Washington" ;
#     :day "2" ;
#     :gender "Male" ;
#     :month "November" ;
#     :name "James Covington Jr" ;
#     :race "Unknown" ;
#     :state "DC" ;
#     :year "2015" ;
#     terms:rowID "961" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/962> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "2000 E Kearney St" ;
#     :agency "Springfield Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Springfield" ;
#     :day "4" ;
#     :gender "Male" ;
#     :month "November" ;
#     :name "Unknown" ;
#     :race "Unknown" ;
#     :state "MO" ;
#     :year "2015" ;
#     terms:rowID "962" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/963> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "Drew St and Nettleton St" ;
#     :agency "Houston Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Houston" ;
#     :day "4" ;
#     :gender "Male" ;
#     :month "November" ;
#     :name "Unknown" ;
#     :race "Unknown" ;
#     :state "TX" ;
#     :year "2015" ;
#     terms:rowID "963" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/964> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "5200 Lake Rd" ;
#     :age "18" ;
#     :agency "University of California Police Department" ;
#     :armed "Unknown" ;
#     :cause "Gunshot" ;
#     :city "Merced" ;
#     :day "4" ;
#     :gender "Male" ;
#     :month "November" ;
#     :name "Faisal Mohammad" ;
#     :race "Unknown" ;
#     :state "CA" ;
#     :year "2015" ;
#     terms:rowID "964" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/965> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "Grand Ave and Jewell St" ;
#     :age "47" ;
#     :agency "San Diego Police Department" ;
#     :armed "No" ;
#     :cause "Gunshot" ;
#     :city "San Diego" ;
#     :day "4" ;
#     :gender "Male" ;
#     :month "November" ;
#     :name "Timothy Smith" ;
#     :race "Unknown" ;
#     :state "CA" ;
#     :year "2015" ;
#     terms:rowID "965" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/966> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "10100 Puttington Dr" ;
#     :age "30" ;
#     :agency "Lakeshire Police Department, St Louis County Police Department" ;
#     :armed "Other" ;
#     :cause "Gunshot" ;
#     :city "Lakeshire" ;
#     :day "5" ;
#     :gender "Male" ;
#     :month "November" ;
#     :name "Jacob Hohman" ;
#     :race "White" ;
#     :state "MO" ;
#     :year "2015" ;
#     terms:rowID "966" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/967> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "Whisper Way" ;
#     :age "36" ;
#     :agency "Berkeley County Sheriff's Office" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Goose Creek" ;
#     :day "5" ;
#     :gender "Female" ;
#     :month "November" ;
#     :name "Laura Lemieux" ;
#     :race "Unknown" ;
#     :state "SC" ;
#     :year "2015" ;
#     terms:rowID "967" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/968> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1043 Charles Ave" ;
#     :age "46" ;
#     :agency "Monongalia County Sheriff’s Office" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Morgantown" ;
#     :day "5" ;
#     :gender "Male" ;
#     :month "November" ;
#     :name "David Romonaski" ;
#     :race "Unknown" ;
#     :state "WV" ;
#     :year "2015" ;
#     terms:rowID "968" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/969> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "Oklahoma Hwy 20" ;
#     :agency "Skiatook Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Hominy" ;
#     :day "5" ;
#     :gender "Male" ;
#     :month "November" ;
#     :name "Unknown" ;
#     :race "Unknown" ;
#     :state "OK" ;
#     :year "2015" ;
#     terms:rowID "969" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/97> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "4304 Pershing Pointe Pl" ;
#     :age "37" ;
#     :agency "Orlando Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Orlando" ;
#     :day "4" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Izzy Colon" ;
#     :race "Hispanic/Latino" ;
#     :state "FL" ;
#     :year "2015" ;
#     terms:rowID "97" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/970> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "Martin Luther King Dr" ;
#     :age "6" ;
#     :agency "Ward 2 city marshals" ;
#     :armed "No" ;
#     :cause "Gunshot" ;
#     :city "Marksville" ;
#     :day "3" ;
#     :gender "Male" ;
#     :month "November" ;
#     :name "Jeremy Mardis" ;
#     :race "White" ;
#     :state "LA" ;
#     :year "2015" ;
#     terms:rowID "970" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/971> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "1015 NW 22nd Ave" ;
#     :agency "Portland Police Bureau" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Portland" ;
#     :day "6" ;
#     :gender "Male" ;
#     :month "November" ;
#     :name "Unknown" ;
#     :race "Unknown" ;
#     :state "OR" ;
#     :year "2015" ;
#     terms:rowID "971" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/972> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "S Maryland Pkwy & E Wigwam Ave" ;
#     :agency "Clark County School District Police Department" ;
#     :armed "Vehicle" ;
#     :cause "Gunshot" ;
#     :city "Las Vegas" ;
#     :day "6" ;
#     :gender "Male" ;
#     :month "November" ;
#     :name "Unknown" ;
#     :race "Unknown" ;
#     :state "NV" ;
#     :year "2015" ;
#     terms:rowID "972" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/98> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "I-35" ;
#     :age "51" ;
#     :agency "Waco Police Department, McLennan County Sheriff's Office" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Waco" ;
#     :day "4" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Jimmy Robinson Jr" ;
#     :race "Black" ;
#     :state "TX" ;
#     :year "2015" ;
#     terms:rowID "98" .
#
# <http://opendata.socrata.com/resource/_7vma-c64n/99> a <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person>,
#         owl:NamedIndividual ;
#     :address "7100 Pine Ave" ;
#     :age "59" ;
#     :agency "Corona Police Department" ;
#     :armed "Firearm" ;
#     :cause "Gunshot" ;
#     :city "Chino" ;
#     :day "4" ;
#     :gender "Male" ;
#     :month "February" ;
#     :name "Paul Johnson" ;
#     :race "White" ;
#     :state "CA" ;
#     :year "2015" ;
#     terms:rowID "99" .
#
# terms:rowID a owl:AnnotationProperty .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Armed> a owl:Class ;
#     rdfs:subClassOf <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Day> a owl:Class ;
#     rdfs:subClassOf <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Month> a owl:Class ;
#     rdfs:subClassOf <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Name> a owl:Class ;
#     rdfs:subClassOf <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Year> a owl:Class ;
#     rdfs:subClassOf <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#hasHomicideByAgency> a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> ;
#     rdfs:range <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Agency> .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#hasRace> a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> ;
#     rdfs:range <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Race> .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#isAgeOf> a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Age> ;
#     rdfs:range <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> ;
#     rdfs:subPropertyOf owl:topObjectProperty .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#isCauseOfDeath> a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Cause> ;
#     rdfs:range <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#isGenderOf> a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Gender> ;
#     rdfs:range <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#livedInState> a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> ;
#     rdfs:range :State .
#
# :Homicide a owl:Class .
#
# :hadAddress a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> ;
#     rdfs:range :Address .
#
# :livedInCity a owl:InverseFunctionalProperty,
#         owl:ObjectProperty ;
#     rdfs:domain <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> ;
#     rdfs:range :City .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Age> a owl:Class ;
#     rdfs:subClassOf <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Agency> a owl:Class ;
#     rdfs:subClassOf <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Cause> a owl:Class ;
#     rdfs:subClassOf <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Gender> a owl:Class ;
#     rdfs:subClassOf <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Race> a owl:Class ;
#     rdfs:subClassOf <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> .
#
# :Address a owl:Class ;
#     rdfs:subClassOf <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> .
#
# :City a owl:Class ;
#     rdfs:subClassOf <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> .
#
# :State a owl:Class ;
#     rdfs:subClassOf <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> .
#
# <http://lamp.cse.fau.edu/~dterrel3/PoliceHomicides#Person> a owl:Class ;
#     rdfs:subClassOf :Homicide .

# %%
policeKillings = g.query("""
    SELECT ?state ?city ?race ?name ?armed ?cause ?age
         {  
            # ?s :state ?state .
            # ?s :city   ?city  .
            # ?s :race  ?race .
            # ?s :name  ?name .
            # ?s :armed  ?armed .
            # ?s :cause  ?cause .
            # ?s :age  ?age .
            FILTER regex(?race, "^", "i")}
            LIMIT 50
    """)
#Print out Query
print("----------------------------- Police Homicides 2015 Figures------------------------\n")
headers = ['state','city','race','name','armed','cause','age']
#deathsByRace = tabulate(policeKillings,headers, tablefmt="fancy_grid")
deathsByRace = tabulate(policeKillings,headers)
print deathsByRace
# Out:
# ----------------------------- Police Homicides 2015 Figures------------------------
#
# state    city               race                    name                               armed               cause                age
# -------  -----------------  ----------------------  ---------------------------------  ------------------  -----------------  -----
# OH       Peebles            White                   Robert Rooker                      Vehicle             Gunshot               26
# CA       Elk Grove          Hispanic/Latino         Luis Chavez-Diaz                   Firearm             Gunshot               27
# TX       Dallas             Black                   Colby Robinson                     Unknown             Gunshot               26
# NY       Rochester          Black                   Richard Davis                      No                  Taser                 50
# CA       Burbank            Hispanic/Latino         Sergio Navas                       No                  Gunshot               34
# CA       Santa Maria        Hispanic/Latino         Jesus Gomez                        Firearm             Gunshot               50
# MD       Frederick          Unknown                 Kevin Brunson                      Unknown             Gunshot               45
# MO       Kansas City        Black                   Tyrone Holman                      Other               Gunshot               37
# WI       Fond du Lac        White                   Steven Snyder                      Firearm             Gunshot               37
# IL       Marion             White                   Joshua Green                       Firearm             Gunshot               27
# TX       Onalaska           White                   Eugene Smith II                    Firearm             Gunshot               20
# IN       Monon              Black                   Don Smith                          Firearm             Gunshot               29
# FL       Palm Bay           White                   Bradford Leonard                   Firearm             Gunshot               50
# CA       San Francisco      Asian/Pacific Islander  Filimoni Raiyawa                   No                  Death in custody      57
# NJ       Hamilton Township  White                   Shawn Clyde                        Knife               Gunshot               36
# CA       Calexico           Hispanic/Latino         Miguel Galena                      Knife               Gunshot               35
# FL       Miami Gardens      Black                   Lavall Hall                        Other               Gunshot               25
# LA       Houma              White                   Jean Paul Falgout                  Non-lethal firearm  Gunshot               45
# LA       Baton Rouge        Black                   Jamie Croom                        Firearm             Gunshot               31
# NC       Winston-Salem      White                   Alan Dunnagan                      No                  Struck by vehicle     68
# IL       River Forest       Unknown                 Matthew Watson                     Firearm             Gunshot               24
# CA       Olivehurst         White                   Billy Maine                        Firearm             Gunshot               31
# GA       Brinson            White                   Roger Braswell                     Firearm             Gunshot               50
# CA       Hawaiian Gardens   Hispanic/Latino         Johnny Ray Anderson                No                  Gunshot               43
# TN       Columbia           Unknown                 Raymond Phillips                   Firearm             Gunshot               86
# GA       Augusta            White                   Tyler Wicks                        Firearm             Gunshot               30
# WI       Kenosha            White                   Aaron Siler                        Unknown             Gunshot               26
# VA       Virginia Beach     Black                   India Kager                        No                  Gunshot               28
# NH       Derry              White                   Andrew Toto                        Firearm             Gunshot               54
# OK       Bunch              White                   Billy Patrick                      No                  Gunshot               29
# AZ       Phoenix            White                   Kevin Snyder                       Firearm             Gunshot               46
# CA       Pajaro             Hispanic/Latino         Alejandro Fernandez                Firearm             Gunshot               45
# OK       Oklahoma City      Black                   Herbert Hill                       Firearm             Gunshot               26
# ID       Middleton          White                   Brandon Rapp                       Firearm             Gunshot               31
# FL       North Miami        Unknown                 Junior Prosper                     No                  Gunshot               31
# CT       Bolton             White                   Christopher Anderson               Knife               Gunshot               53
# CA       San Diego          White                   Fridoon Rawshannehad               No                  Gunshot               42
# IN       Indianapolis       Unknown                 Ronny Bowling                      No                  Struck by vehicle     53
# PA       Girardville        White                   Lucas Markus                       No                  Taser                 33
# LA       Marksville         White                   Jeremy Mardis                      No                  Gunshot                6
# OK       Tulsa              Black                   Rodney Walker                      Firearm             Gunshot               23
# AZ       Prescott           White                   Arthur Bates                       Firearm             Gunshot               45
# TX       Roma               Hispanic/Latino         Miguel Anguel de Santos-Rodriguez  Firearm             Gunshot               36
# GA       Eatonton           White                   Harry Davis                        Knife               Gunshot               57
# TX       Houston            Hispanic/Latino         Edelmiro Hernandez                 Knife               Gunshot               33
# TX       Dallas             Black                   Bertrand Davis                     Non-lethal firearm  Gunshot               43
# IL       Rantoul            Black                   Darius Graves                      Other               Gunshot               31
# CA       Fremont            Unknown                 Zaki Shinwary                      Knife               Gunshot               48
# CA       Ontario            Hispanic/Latino         Luis Wenceslao                     Other               Gunshot               32
# OK       Tahlequah          White                   Joshua Crittenden                  Firearm             Gunshot               35

# %%
#Displaying the number of deaths for each race
#Running SPARQL Query to aggregaete RDF data
tbr = g.query("""
    SELECT DISTINCT ?race (COUNT(?race) AS ?rCount)
    WHERE{?s :race ?race.}
    GROUP BY ?race 
    ORDER BY DESC(?rCount)
    """)
#Print out Query
print("-----------------------------Total Homicides caused by Police ordered by Race------------------------\n")
headers2 = ['race','TOTAL DEATHS' ]
print tabulate(tbr,headers2,tablefmt="fancy_grid")
# Out:
# -----------------------------Total Homicides caused by Police ordered by Race------------------------
#
# ╒════════════════════════╤════════════════╕
# │ race                   │   TOTAL DEATHS │
# ╞════════════════════════╪════════════════╡
# │ White                  │            445 │
# ├────────────────────────┼────────────────┤
# │ Black                  │            232 │
# ├────────────────────────┼────────────────┤
# │ Hispanic/Latino        │            144 │
# ├────────────────────────┼────────────────┤
# │ Unknown                │            118 │
# ├────────────────────────┼────────────────┤
# │ Asian/Pacific Islander │             17 │
# ├────────────────────────┼────────────────┤
# │ Native American        │             12 │
# ├────────────────────────┼────────────────┤
# │ Arab-American          │              3 │
# ├────────────────────────┼────────────────┤
# │ Other                  │              1 │
# ╘════════════════════════╧════════════════╛

# %%
#Displaying the number of deaths for each race
#Running SPARQL Query to aggregaete RDF data
la = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "Los Angeles", "i") ||
            regex(?city, "Pomona", "i")||
            regex(?city, "Long Beach", "i")||
            regex(?city, "Needles", "i")||
            regex(?agency, "Long Beach", "i")||
            regex(?agency, "Los Angeles", "i")||
            regex(?city, "South El Monte", "i"))}
    ORDER BY DESC(?cCount)
    """)
headers2 = ['Agency','Metro Area','TOTAL DEATHS' ]
print tabulate(la,headers2,tablefmt="fancy_grid")
houst = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "Houston", "i") ||
            regex(?city, "Missouri City", "i")||
            regex(?agency, "Missouri City", "i")||
            regex(?agency, "Houston", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(houst,headers2,tablefmt="fancy_grid")
mia = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "West Palm Beach", "i")||
            regex(?city, "Miami", "i")||
            regex(?agency, "Palm Beach", "i")||
            regex(?agency, "Broward", "i")||
            regex(?agency, "Fort Lauderdale", "i")||
            regex(?agency, "Miami", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(mia,headers2,tablefmt="fancy_grid")
ny = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "New York", "i")||
            regex(?city, "Newark", "i")||
            regex(?city, "Jersey City", "i")||
            regex(?agency, "Jersey City", "i")||
            regex(?agency, "Newark", "i")||
            regex(?agency, "New York", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(ny,headers2,tablefmt="fancy_grid")
bal = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "Baltimore", "i")||
            regex(?city, "Columbia", "i")||
            regex(?city, "Towson", "i")||
            regex(?agency, "Baltimore", "i")||
            regex(?agency, "Columbia", "i")||
            regex(?agency, "Towson", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(bal,headers2,tablefmt="fancy_grid")
bos = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "Boston", "i")||
            regex(?city, "Cambridge", "i")||
            regex(?city, "Newton", "i")||
            regex(?agency, "Boston", "i")||
            regex(?agency, "Cambridge", "i")||
            regex(?agency, "Newton", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(bos,headers2,tablefmt="fancy_grid")
char = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "Charlotte", "i")||
            regex(?city, "Concord", "i")||
            regex(?city, "Gastonia,", "i")||
            regex(?agency, "Charlotte", "i")||
            regex(?agency, "Concord", "i")||
            regex(?agency, "Gastonia,", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(char,headers2,tablefmt="fancy_grid")
atl = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "Atlanta", "i")||
            regex(?city, "Roswell", "i")||
            regex(?agency, "Sandy Springs", "i")||
            regex(?city, "Sandy Springs", "i")||
            regex(?agency, "Roswell", "i")||
            regex(?agency, "Atlanta", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(atl,headers2,tablefmt="fancy_grid")
chi = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "Chicago", "i")||
            regex(?agency, "Chicago", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(chi,headers2,tablefmt="fancy_grid")
phoe = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "Phoenix", "i")||
           regex(?city, "Mesa", "i")||
           regex(?city, "Scottsdale", "i")||
           regex(?agency, "Phoenix", "i")||
           regex(?agency, "Mesa", "i")||
            regex(?agency, "Scottsdale", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(phoe,headers2,tablefmt="fancy_grid")
dal = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "Dallas", "i")||
            regex(?city, "Fort Worth", "i")||
            regex(?city, "Arlington", "i")||
            regex(?agency, "Fort Worth", "i")||
            regex(?agency, "Dallas", "i")||
            regex(?agency, "Arlington", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(dal,headers2,tablefmt="fancy_grid")
detr = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "Detroit", "i")||
            regex(?city, "Warren", "i")||
            regex(?city, "Dearborn", "i")||
            regex(?agency, "Detroit", "i")||
            regex(?agency, "Warren", "i")||
            regex(?agency, "Dearborn", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(detr,headers2,tablefmt="fancy_grid")
denv = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "Denver", "i")||
            regex(?city, "Aurora", "i")||
            regex(?city, "Lakewood", "i")||
            regex(?agency, "Denver", "i")||
            regex(?agency, "Aurora", "i")||
            regex(?agency, "Lakewood", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(denv,headers2,tablefmt="fancy_grid")
minn = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "Minneapolis", "i")||
            regex(?city, "St Paul", "i")||
            regex(?city, "Bloomington", "i")||
            regex(?agency, "Minneapolis", "i")||
            regex(?agency, "St Paul", "i")||
            regex(?agency, "Bloomington", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(minn,headers2,tablefmt="fancy_grid")
phil = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "Philadelphia", "i")||
            regex(?city, "Camden", "i")||
            regex(?city, "Wilmington", "i")||
            regex(?agency, "Philadelphia", "i")||
            regex(?agency, "Camden", "i")||
            regex(?agency, "Wilmington", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(phil,headers2,tablefmt="fancy_grid")
pitt = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "Pittsburgh", "i")||
            regex(?agency, "Pittsburgh", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(pitt,headers2,tablefmt="fancy_grid")
port = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "Portland", "i")||
            regex(?city, "Vancouver", "i")||
            regex(?city, "Hillsboro", "i")||
            regex(?agency, "Portland", "i")||
            regex(?agency, "Vancouver", "i")||
            regex(?agency, "Hillsboro", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(port,headers2,tablefmt="fancy_grid")
rivers = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "Riverside", "i")||
            regex(?city, "San Bernardino", "i")||
            regex(?city, "Ontario", "i")||
            regex(?agency, "Riverside", "i")||
            regex(?agency, "San Bernardino", "i")||
            regex(?agency, "Ontario", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(rivers,headers2,tablefmt="fancy_grid")
stl = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "St Louis", "i")||
            regex(?agency, "St Louis", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(stl,headers2,tablefmt="fancy_grid")
sanant = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "San Antonio", "i")||
            regex(?city, "New Braunfels", "i")||
            regex(?agency, "San Antonio", "i")||
            regex(?agency, "New Braunfels", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(sanant,headers2,tablefmt="fancy_grid")
sand = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "San Diego", "i")||
            regex(?city, "Carlsbad", "i")||
            regex(?agency, "San Diego", "i")||
            regex(?agency, "Carlsbad", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(sand,headers2,tablefmt="fancy_grid")
sanf = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "San Francisco", "i")||
            regex(?city, "Oakland", "i")||
            regex(?city, "Hayward", "i")||
            regex(?agency, "San Francisco", "i")||
            regex(?agency, "Hayward", "i")||
            regex(?agency, "Oakland", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(sanf,headers2,tablefmt="fancy_grid")
seat = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "Seattle", "i")||
            regex(?city, "Tacoma", "i")||
            regex(?city, "Bellevue", "i")||
            regex(?agency, "Seattle", "i")||
            regex(?agency, "Tacoma", "i")||
            regex(?agency, "Bellevue", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(seat,headers2,tablefmt="fancy_grid")
tamp = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "Tampa", "i")||
            regex(?city, "St Petersburg", "i")||
            regex(?city, "Clearwater", "i")||
            regex(?agency, "Tampa", "i")||
            regex(?agency, "St Petersburg", "i")||
            regex(?agency, "Clearwater", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(tamp,headers2,tablefmt="fancy_grid")
dc = g.query("""
    SELECT DISTINCT ?agency ?city (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
    FILTER (regex(?city, "Washington", "i")||
            regex(?city, "Arlington", "i")||
            regex(?city, "Alexandria", "i")||
            regex(?agency, "Washington", "i")||
            regex(?agency, "Arlington", "i")||
            regex(?agency, "Alexandria", "i"))}
    ORDER BY DESC(?cCount)
    """)
print tabulate(dc,headers2,tablefmt="fancy_grid")
# Out:
# ╒═══════════════════════════════╤══════════════╤════════════════╕
# │ Agency                        │ Metro Area   │   TOTAL DEATHS │
# ╞═══════════════════════════════╪══════════════╪════════════════╡
# │ Los Angeles Police Department │ Los Angeles  │             40 │
# ╘═══════════════════════════════╧══════════════╧════════════════╛
# ╒════════════════════════════════╤══════════════╤════════════════╕
# │ Agency                         │ Metro Area   │   TOTAL DEATHS │
# ╞════════════════════════════════╪══════════════╪════════════════╡
# │ Harris County Sheriff's Office │ Houston      │             16 │
# ╘════════════════════════════════╧══════════════╧════════════════╛
# ╒══════════════════════════════════════╤════════════════════╤════════════════╕
# │ Agency                               │ Metro Area         │   TOTAL DEATHS │
# ╞══════════════════════════════════════╪════════════════════╪════════════════╡
# │ Palm Beach Gardens Police Department │ Palm Beach Gardens │             17 │
# ╘══════════════════════════════════════╧════════════════════╧════════════════╛
# ╒════════════════════════════╤══════════════╤════════════════╕
# │ Agency                     │ Metro Area   │   TOTAL DEATHS │
# ╞════════════════════════════╪══════════════╪════════════════╡
# │ New York Police Department │ New York     │             14 │
# ╘════════════════════════════╧══════════════╧════════════════╛
# ╒══════════════════════════════════════════════════════════════╤══════════════╤════════════════╕
# │ Agency                                                       │ Metro Area   │   TOTAL DEATHS │
# ╞══════════════════════════════════════════════════════════════╪══════════════╪════════════════╡
# │ Columbia Police Department and University of Missouri Police │ Columbia     │             11 │
# ╘══════════════════════════════════════════════════════════════╧══════════════╧════════════════╛
# ╒══════════════════════════╤══════════════╤════════════════╕
# │ Agency                   │ Metro Area   │   TOTAL DEATHS │
# ╞══════════════════════════╪══════════════╪════════════════╡
# │ Boston Police Department │ Roxbury      │              4 │
# ╘══════════════════════════╧══════════════╧════════════════╛
# ╒═════════════════════════════════════════╤══════════════╤════════════════╕
# │ Agency                                  │ Metro Area   │   TOTAL DEATHS │
# ╞═════════════════════════════════════════╪══════════════╪════════════════╡
# │ Charlotte-Mecklenburg Police Department │ Charlotte    │              1 │
# ╘═════════════════════════════════════════╧══════════════╧════════════════╛
# ╒═══════════════════════════╤══════════════╤════════════════╕
# │ Agency                    │ Metro Area   │   TOTAL DEATHS │
# ╞═══════════════════════════╪══════════════╪════════════════╡
# │ Atlanta Police Department │ Atlanta      │              4 │
# ╘═══════════════════════════╧══════════════╧════════════════╛
# ╒═══════════════════════════╤══════════════╤════════════════╕
# │ Agency                    │ Metro Area   │   TOTAL DEATHS │
# ╞═══════════════════════════╪══════════════╪════════════════╡
# │ Chicago Police Department │ Chicago      │              7 │
# ╘═══════════════════════════╧══════════════╧════════════════╛
# ╒═══════════════════════════╤══════════════╤════════════════╕
# │ Agency                    │ Metro Area   │   TOTAL DEATHS │
# ╞═══════════════════════════╪══════════════╪════════════════╡
# │ Phoenix Police Department │ Phoenix      │             15 │
# ╘═══════════════════════════╧══════════════╧════════════════╛
# ╒═════════════════════════════╤══════════════╤════════════════╕
# │ Agency                      │ Metro Area   │   TOTAL DEATHS │
# ╞═════════════════════════════╪══════════════╪════════════════╡
# │ Arlington Police Department │ Arlington    │             16 │
# ╘═════════════════════════════╧══════════════╧════════════════╛
# ╒═══════════════════════════╤══════════════╤════════════════╕
# │ Agency                    │ Metro Area   │   TOTAL DEATHS │
# ╞═══════════════════════════╪══════════════╪════════════════╡
# │ Detroit Police Department │ Detroit      │              4 │
# ╘═══════════════════════════╧══════════════╧════════════════╛
# ╒════════════════════════════╤══════════════╤════════════════╕
# │ Agency                     │ Metro Area   │   TOTAL DEATHS │
# ╞════════════════════════════╪══════════════╪════════════════╡
# │ Lakewood Police Department │ Lakewood     │              6 │
# ╘════════════════════════════╧══════════════╧════════════════╛
# ╒═══════════════════════════╤══════════════╤════════════════╕
# │ Agency                    │ Metro Area   │   TOTAL DEATHS │
# ╞═══════════════════════════╪══════════════╪════════════════╡
# │ St Paul Police Department │ St Paul      │              6 │
# ╘═══════════════════════════╧══════════════╧════════════════╛
# ╒══════════════════════════════════════════════════════════════════════╤══════════════╤════════════════╕
# │ Agency                                                               │ Metro Area   │   TOTAL DEATHS │
# ╞══════════════════════════════════════════════════════════════════════╪══════════════╪════════════════╡
# │ Southeastern Pennsylvania Transportation Authority Police Department │ Philadelphia │              6 │
# ╘══════════════════════════════════════════════════════════════════════╧══════════════╧════════════════╛
# ╒═══════════════════════════════════════════════════════════════════════════════════╤══════════════╤════════════════╕
# │ Agency                                                                            │ Metro Area   │   TOTAL DEATHS │
# ╞═══════════════════════════════════════════════════════════════════════════════════╪══════════════╪════════════════╡
# │ US Marshals Service, Pennsylvania State Police, Allegheny County Sheriff's Office │ Pittsburgh   │              2 │
# ╘═══════════════════════════════════════════════════════════════════════════════════╧══════════════╧════════════════╛
# ╒════════════════════════╤══════════════╤════════════════╕
# │ Agency                 │ Metro Area   │   TOTAL DEATHS │
# ╞════════════════════════╪══════════════╪════════════════╡
# │ Portland Police Bureau │ Portland     │              5 │
# ╘════════════════════════╧══════════════╧════════════════╛
# ╒═══════════════════════════════════════╤══════════════╤════════════════╕
# │ Agency                                │ Metro Area   │   TOTAL DEATHS │
# ╞═══════════════════════════════════════╪══════════════╪════════════════╡
# │ Riverside County Sheriff's Department │ Aguanga      │             16 │
# ╘═══════════════════════════════════════╧══════════════╧════════════════╛
# ╒════════════════════════════════════════════════════════════════════════════════════════════════════════╤══════════════╤════════════════╕
# │ Agency                                                                                                 │ Metro Area   │   TOTAL DEATHS │
# ╞════════════════════════════════════════════════════════════════════════════════════════════════════════╪══════════════╪════════════════╡
# │ St Louis County Police Department, Jefferson County Sheriff's Office, Franklin County Sheriff's Office │ Robertsville │              7 │
# ╘════════════════════════════════════════════════════════════════════════════════════════════════════════╧══════════════╧════════════════╛
# ╒═══════════════════════════════╤══════════════╤════════════════╕
# │ Agency                        │ Metro Area   │   TOTAL DEATHS │
# ╞═══════════════════════════════╪══════════════╪════════════════╡
# │ San Antonio Police Department │ San Antonio  │              7 │
# ╘═══════════════════════════════╧══════════════╧════════════════╛
# ╒═══════════════════════════════════════════════════════════╤══════════════╤════════════════╕
# │ Agency                                                    │ Metro Area   │   TOTAL DEATHS │
# ╞═══════════════════════════════════════════════════════════╪══════════════╪════════════════╡
# │ Carlsbad Police Department, Lake Arthur Police Department │ Artesia      │             11 │
# ╘═══════════════════════════════════════════════════════════╧══════════════╧════════════════╛
# ╒═════════════════════════════════╤═══════════════╤════════════════╕
# │ Agency                          │ Metro Area    │   TOTAL DEATHS │
# ╞═════════════════════════════════╪═══════════════╪════════════════╡
# │ San Francisco Police Department │ San Francisco │             13 │
# ╘═════════════════════════════════╧═══════════════╧════════════════╛
# ╒══════════════════════════╤══════════════╤════════════════╕
# │ Agency                   │ Metro Area   │   TOTAL DEATHS │
# ╞══════════════════════════╪══════════════╪════════════════╡
# │ Tacoma Police Department │ Tacoma       │              3 │
# ╘══════════════════════════╧══════════════╧════════════════╛
# ╒═════════════════════════════════╤═══════════════╤════════════════╕
# │ Agency                          │ Metro Area    │   TOTAL DEATHS │
# ╞═════════════════════════════════╪═══════════════╪════════════════╡
# │ St Petersburg Police Department │ St Petersburg │              4 │
# ╘═════════════════════════════════╧═══════════════╧════════════════╛
# ╒═════════════════════════════╤══════════════╤════════════════╕
# │ Agency                      │ Metro Area   │   TOTAL DEATHS │
# ╞═════════════════════════════╪══════════════╪════════════════╡
# │ Arlington Police Department │ Arlington    │             12 │
# ╘═════════════════════════════╧══════════════╧════════════════╛

# %%
#Displaying the number of deaths for each race
#Running SPARQL Query to aggregaete RDF data
la = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "Los Angeles", "i") ||
            regex(?city, "Pomona", "i")||
            regex(?city, "Long Beach", "i")||
            regex(?city, "Needles", "i")||
            regex(?agency, "Long Beach", "i")||
            regex(?agency, "Los Angeles", "i")||
            regex(?city, "South El Monte", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
headers2 = ['Agency','Metro Area','Race','TOTAL DEATHS' ]
print tabulate(la,headers2,tablefmt="fancy_grid")
houst = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "Houston", "i") ||
            regex(?city, "Missouri City", "i")||
            regex(?agency, "Missouri City", "i")||
            regex(?agency, "Houston", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(houst,headers2,tablefmt="fancy_grid")
mia = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "West Palm Beach", "i")||
            regex(?city, "Miami", "i")||
            regex(?agency, "Palm Beach", "i")||
            regex(?agency, "Broward", "i")||
            regex(?agency, "Fort Lauderdale", "i")||
            regex(?agency, "Miami", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(mia,headers2,tablefmt="fancy_grid")
ny = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "New York", "i")||
            regex(?city, "Newark", "i")||
            regex(?city, "Jersey City", "i")||
            regex(?agency, "Jersey City", "i")||
            regex(?agency, "Newark", "i")||
            regex(?agency, "New York", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(ny,headers2,tablefmt="fancy_grid")
bal = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "Baltimore", "i")||
            regex(?city, "Columbia", "i")||
            regex(?city, "Towson", "i")||
            regex(?agency, "Baltimore", "i")||
            regex(?agency, "Columbia", "i")||
            regex(?agency, "Towson", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)    
    """)
print tabulate(bal,headers2,tablefmt="fancy_grid")
bos = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "Boston", "i")||
            regex(?city, "Cambridge", "i")||
            regex(?city, "Newton", "i")||
            regex(?agency, "Boston", "i")||
            regex(?agency, "Cambridge", "i")||
            regex(?agency, "Newton", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(bos,headers2,tablefmt="fancy_grid")
char = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "Charlotte", "i")||
            regex(?city, "Concord", "i")||
            regex(?city, "Gastonia,", "i")||
            regex(?agency, "Charlotte", "i")||
            regex(?agency, "Concord", "i")||
            regex(?agency, "Gastonia,", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(char,headers2,tablefmt="fancy_grid")
atl = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "Atlanta", "i")||
            regex(?city, "Roswell", "i")||
            regex(?agency, "Sandy Springs", "i")||
            regex(?city, "Sandy Springs", "i")||
            regex(?agency, "Roswell", "i")||
            regex(?agency, "Atlanta", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(atl,headers2,tablefmt="fancy_grid")
chi = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "Chicago", "i")||
            regex(?agency, "Chicago", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(chi,headers2,tablefmt="fancy_grid")
phoe = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "Phoenix", "i")||
           regex(?city, "Mesa", "i")||
           regex(?city, "Scottsdale", "i")||
           regex(?agency, "Phoenix", "i")||
           regex(?agency, "Mesa", "i")||
            regex(?agency, "Scottsdale", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(phoe,headers2,tablefmt="fancy_grid")
dal = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "Dallas", "i")||
            regex(?city, "Fort Worth", "i")||
            regex(?city, "Arlington", "i")||
            regex(?agency, "Fort Worth", "i")||
            regex(?agency, "Dallas", "i")||
            regex(?agency, "Arlington", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(dal,headers2,tablefmt="fancy_grid")
detr = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "Detroit", "i")||
            regex(?city, "Warren", "i")||
            regex(?city, "Dearborn", "i")||
            regex(?agency, "Detroit", "i")||
            regex(?agency, "Warren", "i")||
            regex(?agency, "Dearborn", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(detr,headers2,tablefmt="fancy_grid")
denv = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "Denver", "i")||
            regex(?city, "Aurora", "i")||
            regex(?city, "Lakewood", "i")||
            regex(?agency, "Denver", "i")||
            regex(?agency, "Aurora", "i")||
            regex(?agency, "Lakewood", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(denv,headers2,tablefmt="fancy_grid")
minn = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "Minneapolis", "i")||
            regex(?city, "St Paul", "i")||
            regex(?city, "Bloomington", "i")||
            regex(?agency, "Minneapolis", "i")||
            regex(?agency, "St Paul", "i")||
            regex(?agency, "Bloomington", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(minn,headers2,tablefmt="fancy_grid")
phil = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "Philadelphia", "i")||
            regex(?city, "Camden", "i")||
            regex(?city, "Wilmington", "i")||
            regex(?agency, "Philadelphia", "i")||
            regex(?agency, "Camden", "i")||
            regex(?agency, "Wilmington", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(phil,headers2,tablefmt="fancy_grid")
pitt = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "Pittsburgh", "i")||
            regex(?agency, "Pittsburgh", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(pitt,headers2,tablefmt="fancy_grid")
port = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "Portland", "i")||
            regex(?city, "Vancouver", "i")||
            regex(?city, "Hillsboro", "i")||
            regex(?agency, "Portland", "i")||
            regex(?agency, "Vancouver", "i")||
            regex(?agency, "Hillsboro", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(port,headers2,tablefmt="fancy_grid")
rivers = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "Riverside", "i")||
            regex(?city, "San Bernardino", "i")||
            regex(?city, "Ontario", "i")||
            regex(?agency, "Riverside", "i")||
            regex(?agency, "San Bernardino", "i")||
            regex(?agency, "Ontario", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(rivers,headers2,tablefmt="fancy_grid")
stl = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "St Louis", "i")||
            regex(?agency, "St Louis", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(stl,headers2,tablefmt="fancy_grid")
sanant = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "San Antonio", "i")||
            regex(?city, "New Braunfels", "i")||
            regex(?agency, "San Antonio", "i")||
            regex(?agency, "New Braunfels", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(sanant,headers2,tablefmt="fancy_grid")
sand = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "San Diego", "i")||
            regex(?city, "Carlsbad", "i")||
            regex(?agency, "San Diego", "i")||
            regex(?agency, "Carlsbad", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(sand,headers2,tablefmt="fancy_grid")
sanf = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "San Francisco", "i")||
            regex(?city, "Oakland", "i")||
            regex(?city, "Hayward", "i")||
            regex(?agency, "San Francisco", "i")||
            regex(?agency, "Hayward", "i")||
            regex(?agency, "Oakland", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(sanf,headers2,tablefmt="fancy_grid")
seat = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "Seattle", "i")||
            regex(?city, "Tacoma", "i")||
            regex(?city, "Bellevue", "i")||
            regex(?agency, "Seattle", "i")||
            regex(?agency, "Tacoma", "i")||
            regex(?agency, "Bellevue", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(seat,headers2,tablefmt="fancy_grid")
tamp = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "Tampa", "i")||
            regex(?city, "St Petersburg", "i")||
            regex(?city, "Clearwater", "i")||
            regex(?agency, "Tampa", "i")||
            regex(?agency, "St Petersburg", "i")||
            regex(?agency, "Clearwater", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(tamp,headers2,tablefmt="fancy_grid")
dc = g.query("""
    SELECT DISTINCT ?agency ?city ?race (COUNT(*) AS ?cCount)
    WHERE{?s :city ?city .
          # ?s :agency ?agency .
          # ?s :race ?race .
    FILTER (regex(?city, "Washington", "i")||
            regex(?city, "Arlington", "i")||
            regex(?city, "Alexandria", "i")||
            regex(?agency, "Washington", "i")||
            regex(?agency, "Arlington", "i")||
            regex(?agency, "Alexandria", "i"))}
    GROUP BY ?race
    ORDER BY DESC(?cCount)
    """)
print tabulate(dc,headers2,tablefmt="fancy_grid")
# Out:
# ╒═════════════════════════════════════════╤════════════════╤════════════════════════╤════════════════╕
# │ Agency                                  │ Metro Area     │ Race                   │   TOTAL DEATHS │
# ╞═════════════════════════════════════════╪════════════════╪════════════════════════╪════════════════╡
# │ Los Angeles Police Department           │ Los Angeles    │ Hispanic/Latino        │             19 │
# ├─────────────────────────────────────────┼────────────────┼────────────────────────┼────────────────┤
# │ Los Angeles Police Department           │ Sylmar         │ White                  │              7 │
# ├─────────────────────────────────────────┼────────────────┼────────────────────────┼────────────────┤
# │ Los Angeles County Sheriff's Department │ Cerritos       │ Black                  │              6 │
# ├─────────────────────────────────────────┼────────────────┼────────────────────────┼────────────────┤
# │ Los Angeles Police Department           │ Los Angeles    │ Unknown                │              6 │
# ├─────────────────────────────────────────┼────────────────┼────────────────────────┼────────────────┤
# │ Los Angeles County Sheriff's Department │ South El Monte │ Asian/Pacific Islander │              1 │
# ├─────────────────────────────────────────┼────────────────┼────────────────────────┼────────────────┤
# │ Long Beach Police Department            │ Long Beach     │ Arab-American          │              1 │
# ╘═════════════════════════════════════════╧════════════════╧════════════════════════╧════════════════╛
# ╒═════════════════════════════════════╤═══════════════╤════════════════════════╤════════════════╕
# │ Agency                              │ Metro Area    │ Race                   │   TOTAL DEATHS │
# ╞═════════════════════════════════════╪═══════════════╪════════════════════════╪════════════════╡
# │ Houston County Sheriff's Department │ Houston       │ Hispanic/Latino        │              6 │
# ├─────────────────────────────────────┼───────────────┼────────────────────────┼────────────────┤
# │ Houston Police Department           │ Houston       │ Unknown                │              4 │
# ├─────────────────────────────────────┼───────────────┼────────────────────────┼────────────────┤
# │ Houston Police Department           │ Missouri City │ Black                  │              3 │
# ├─────────────────────────────────────┼───────────────┼────────────────────────┼────────────────┤
# │ Harris County Sheriff's Office      │ Houston       │ White                  │              2 │
# ├─────────────────────────────────────┼───────────────┼────────────────────────┼────────────────┤
# │ Harris County Attorney's Department │ Houston       │ Asian/Pacific Islander │              1 │
# ╘═════════════════════════════════════╧═══════════════╧════════════════════════╧════════════════╛
# ╒══════════════════════════════════════╤════════════════════╤═════════════════╤════════════════╕
# │ Agency                               │ Metro Area         │ Race            │   TOTAL DEATHS │
# ╞══════════════════════════════════════╪════════════════════╪═════════════════╪════════════════╡
# │ Palm Beach Gardens Police Department │ Palm Beach Gardens │ Black           │              8 │
# ├──────────────────────────────────────┼────────────────────┼─────────────────┼────────────────┤
# │ Broward Sheriff's Office             │ Oakland Park       │ White           │              4 │
# ├──────────────────────────────────────┼────────────────────┼─────────────────┼────────────────┤
# │ Palm Beach County Sheriff's Office   │ West Palm Beach    │ Hispanic/Latino │              4 │
# ├──────────────────────────────────────┼────────────────────┼─────────────────┼────────────────┤
# │ Miami-Dade Police Department         │ North Miami        │ Unknown         │              1 │
# ╘══════════════════════════════════════╧════════════════════╧═════════════════╧════════════════╛
# ╒════════════════════════════╤══════════════╤═════════════════╤════════════════╕
# │ Agency                     │ Metro Area   │ Race            │   TOTAL DEATHS │
# ╞════════════════════════════╪══════════════╪═════════════════╪════════════════╡
# │ New York Police Department │ New York     │ Black           │              7 │
# ├────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ New York Police Department │ New York     │ White           │              4 │
# ├────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ New York Police Department │ New York     │ Hispanic/Latino │              2 │
# ├────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ Newark Police Department   │ Newark       │ Unknown         │              1 │
# ╘════════════════════════════╧══════════════╧═════════════════╧════════════════╛
# ╒══════════════════════════════════════════════════════════════╤══════════════╤═════════╤════════════════╕
# │ Agency                                                       │ Metro Area   │ Race    │   TOTAL DEATHS │
# ╞══════════════════════════════════════════════════════════════╪══════════════╪═════════╪════════════════╡
# │ Boone County Sheriff's Department                            │ Columbia     │ Black   │              6 │
# ├──────────────────────────────────────────────────────────────┼──────────────┼─────────┼────────────────┤
# │ Columbia Police Department and University of Missouri Police │ Columbia     │ White   │              3 │
# ├──────────────────────────────────────────────────────────────┼──────────────┼─────────┼────────────────┤
# │ Columbia Police Department                                   │ Columbia     │ Unknown │              2 │
# ╘══════════════════════════════════════════════════════════════╧══════════════╧═════════╧════════════════╛
# ╒════════════════════════════╤══════════════╤═════════════════╤════════════════╕
# │ Agency                     │ Metro Area   │ Race            │   TOTAL DEATHS │
# ╞════════════════════════════╪══════════════╪═════════════════╪════════════════╡
# │ Boston Police Department   │ Roxbury      │ Black           │              3 │
# ├────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ Massachusetts State Police │ Boston       │ Hispanic/Latino │              1 │
# ╘════════════════════════════╧══════════════╧═════════════════╧════════════════╛
# ╒═════════════════════════════════════════╤══════════════╤════════╤════════════════╕
# │ Agency                                  │ Metro Area   │ Race   │   TOTAL DEATHS │
# ╞═════════════════════════════════════════╪══════════════╪════════╪════════════════╡
# │ Charlotte-Mecklenburg Police Department │ Charlotte    │ Black  │              1 │
# ╘═════════════════════════════════════════╧══════════════╧════════╧════════════════╛
# ╒══════════════════════════════════════════════════════════════╤══════════════╤════════╤════════════════╕
# │ Agency                                                       │ Metro Area   │ Race   │   TOTAL DEATHS │
# ╞══════════════════════════════════════════════════════════════╪══════════════╪════════╪════════════════╡
# │ Atlanta Police Department                                    │ Atlanta      │ Black  │              3 │
# ├──────────────────────────────────────────────────────────────┼──────────────┼────────┼────────────────┤
# │ Roswell Police Department and Chaves County Sheriff's Office │ Roswell      │ White  │              1 │
# ╘══════════════════════════════════════════════════════════════╧══════════════╧════════╧════════════════╛
# ╒═══════════════════════════╤══════════════╤═════════════════╤════════════════╕
# │ Agency                    │ Metro Area   │ Race            │   TOTAL DEATHS │
# ╞═══════════════════════════╪══════════════╪═════════════════╪════════════════╡
# │ Chicago Police Department │ Chicago      │ Black           │              3 │
# ├───────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ Chicago Police Department │ Chicago      │ Unknown         │              2 │
# ├───────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ Chicago Police Department │ Chicago      │ Hispanic/Latino │              2 │
# ╘═══════════════════════════╧══════════════╧═════════════════╧════════════════╛
# ╒══════════════════════════════════════════════════════════════════════════════╤══════════════╤═════════════════╤════════════════╕
# │ Agency                                                                       │ Metro Area   │ Race            │   TOTAL DEATHS │
# ╞══════════════════════════════════════════════════════════════════════════════╪══════════════╪═════════════════╪════════════════╡
# │ Phoenix Police Department                                                    │ Phoenix      │ White           │              8 │
# ├──────────────────────────────────────────────────────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ Tempe, Chandler and Mesa Police Departments [US Marshals Service Task Force] │ Phoenix      │ Hispanic/Latino │              3 │
# ├──────────────────────────────────────────────────────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ Phoenix Police Department                                                    │ Phoenix      │ Native American │              2 │
# ├──────────────────────────────────────────────────────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ Scottsdale Police Department                                                 │ Scottsdale   │ Black           │              1 │
# ├──────────────────────────────────────────────────────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ Scottsdale Police Department, Phoenix Police Department                      │ Scottsdale   │ Unknown         │              1 │
# ╘══════════════════════════════════════════════════════════════════════════════╧══════════════╧═════════════════╧════════════════╛
# ╒═════════════════════════════╤══════════════╤═════════════════╤════════════════╕
# │ Agency                      │ Metro Area   │ Race            │   TOTAL DEATHS │
# ╞═════════════════════════════╪══════════════╪═════════════════╪════════════════╡
# │ Arlington Police Department │ Arlington    │ Black           │              8 │
# ├─────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ Dallas Police Department    │ Dallas       │ White           │              4 │
# ├─────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ Dallas Police Department    │ Dallas       │ Hispanic/Latino │              4 │
# ╘═════════════════════════════╧══════════════╧═════════════════╧════════════════╛
# ╒═══════════════════════════╤══════════════╤════════╤════════════════╕
# │ Agency                    │ Metro Area   │ Race   │   TOTAL DEATHS │
# ╞═══════════════════════════╪══════════════╪════════╪════════════════╡
# │ Detroit Police Department │ Detroit      │ Black  │              4 │
# ╘═══════════════════════════╧══════════════╧════════╧════════════════╛
# ╒═════════════════════════════════════════╤══════════════╤═════════════════╤════════════════╕
# │ Agency                                  │ Metro Area   │ Race            │   TOTAL DEATHS │
# ╞═════════════════════════════════════════╪══════════════╪═════════════════╪════════════════╡
# │ Aurora Police Department                │ Aurora       │ Black           │              2 │
# ├─────────────────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ Lakewood Police Department              │ Lakewood     │ Native American │              2 │
# ├─────────────────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ Los Angeles County Sheriff's Department │ Lakewood     │ White           │              1 │
# ├─────────────────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ Denver Police Department                │ Denver       │ Hispanic/Latino │              1 │
# ╘═════════════════════════════════════════╧══════════════╧═════════════════╧════════════════╛
# ╒═══════════════════════════════════╤══════════════╤════════════════════════╤════════════════╕
# │ Agency                            │ Metro Area   │ Race                   │   TOTAL DEATHS │
# ╞═══════════════════════════════════╪══════════════╪════════════════════════╪════════════════╡
# │ St Paul Police Department         │ St Paul      │ White                  │              3 │
# ├───────────────────────────────────┼──────────────┼────────────────────────┼────────────────┤
# │ St Paul Police Department         │ St Paul      │ Black                  │              1 │
# ├───────────────────────────────────┼──────────────┼────────────────────────┼────────────────┤
# │ Brooklyn Center Police Department │ Minneapolis  │ Asian/Pacific Islander │              1 │
# ├───────────────────────────────────┼──────────────┼────────────────────────┼────────────────┤
# │ St Paul Police Department         │ St Paul      │ Unknown                │              1 │
# ╘═══════════════════════════════════╧══════════════╧════════════════════════╧════════════════╛
# ╒══════════════════════════════════════════════════════════════════════╤══════════════╤═════════════════╤════════════════╕
# │ Agency                                                               │ Metro Area   │ Race            │   TOTAL DEATHS │
# ╞══════════════════════════════════════════════════════════════════════╪══════════════╪═════════════════╪════════════════╡
# │ Wilmington Police Department                                         │ Wilmington   │ Black           │              3 │
# ├──────────────────────────────────────────────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ Camden County Police Department                                      │ Camden       │ Hispanic/Latino │              2 │
# ├──────────────────────────────────────────────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ Southeastern Pennsylvania Transportation Authority Police Department │ Philadelphia │ Unknown         │              1 │
# ╘══════════════════════════════════════════════════════════════════════╧══════════════╧═════════════════╧════════════════╛
# ╒═══════════════════════════════════════════════════════════════════════════════════╤══════════════╤════════╤════════════════╕
# │ Agency                                                                            │ Metro Area   │ Race   │   TOTAL DEATHS │
# ╞═══════════════════════════════════════════════════════════════════════════════════╪══════════════╪════════╪════════════════╡
# │ US Marshals Service, Pennsylvania State Police, Allegheny County Sheriff's Office │ Pittsburgh   │ Black  │              2 │
# ╘═══════════════════════════════════════════════════════════════════════════════════╧══════════════╧════════╧════════════════╛
# ╒════════════════════════════╤══════════════╤═════════╤════════════════╕
# │ Agency                     │ Metro Area   │ Race    │   TOTAL DEATHS │
# ╞════════════════════════════╪══════════════╪═════════╪════════════════╡
# │ Portland Police Department │ Portland     │ White   │              4 │
# ├────────────────────────────┼──────────────┼─────────┼────────────────┤
# │ Portland Police Bureau     │ Portland     │ Unknown │              1 │
# ╘════════════════════════════╧══════════════╧═════════╧════════════════╛
# ╒════════════════════════════════════════╤══════════════╤═════════════════╤════════════════╕
# │ Agency                                 │ Metro Area   │ Race            │   TOTAL DEATHS │
# ╞════════════════════════════════════════╪══════════════╪═════════════════╪════════════════╡
# │ San Bernardino County Sheriff's Office │ Pomona       │ Hispanic/Latino │              7 │
# ├────────────────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ Riverside County Sheriff's Department  │ Calimesa     │ White           │              6 │
# ├────────────────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ Riverside County Sheriff's Department  │ Aguanga      │ Unknown         │              3 │
# ╘════════════════════════════════════════╧══════════════╧═════════════════╧════════════════╛
# ╒════════════════════════════════════════════════════════════════════════════════════════════════════════╤══════════════╤════════╤════════════════╕
# │ Agency                                                                                                 │ Metro Area   │ Race   │   TOTAL DEATHS │
# ╞════════════════════════════════════════════════════════════════════════════════════════════════════════╪══════════════╪════════╪════════════════╡
# │ Wellston Police Department                                                                             │ St Louis     │ Black  │              5 │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────┼──────────────┼────────┼────────────────┤
# │ St Louis County Police Department, Jefferson County Sheriff's Office, Franklin County Sheriff's Office │ Robertsville │ White  │              2 │
# ╘════════════════════════════════════════════════════════════════════════════════════════════════════════╧══════════════╧════════╧════════════════╛
# ╒═══════════════════════════════╤══════════════╤═════════════════╤════════════════╕
# │ Agency                        │ Metro Area   │ Race            │   TOTAL DEATHS │
# ╞═══════════════════════════════╪══════════════╪═════════════════╪════════════════╡
# │ San Antonio Police Department │ San Antonio  │ Hispanic/Latino │              5 │
# ├───────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ San Antonio Police Department │ San Antonio  │ White           │              1 │
# ├───────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ San Antonio Police Department │ San Antonio  │ Black           │              1 │
# ╘═══════════════════════════════╧══════════════╧═════════════════╧════════════════╛
# ╒═══════════════════════════════════════════════════════════╤══════════════╤════════════════════════╤════════════════╕
# │ Agency                                                    │ Metro Area   │ Race                   │   TOTAL DEATHS │
# ╞═══════════════════════════════════════════════════════════╪══════════════╪════════════════════════╪════════════════╡
# │ Carlsbad Police Department, Lake Arthur Police Department │ Artesia      │ White                  │              5 │
# ├───────────────────────────────────────────────────────────┼──────────────┼────────────────────────┼────────────────┤
# │ San Diego Police Department                               │ San Diego    │ Unknown                │              3 │
# ├───────────────────────────────────────────────────────────┼──────────────┼────────────────────────┼────────────────┤
# │ San Diego Police Department                               │ San Diego    │ Black                  │              2 │
# ├───────────────────────────────────────────────────────────┼──────────────┼────────────────────────┼────────────────┤
# │ San Diego Police Department                               │ San Diego    │ Asian/Pacific Islander │              1 │
# ╘═══════════════════════════════════════════════════════════╧══════════════╧════════════════════════╧════════════════╛
# ╒════════════════════════════════════╤═══════════════╤════════════════════════╤════════════════╕
# │ Agency                             │ Metro Area    │ Race                   │   TOTAL DEATHS │
# ╞════════════════════════════════════╪═══════════════╪════════════════════════╪════════════════╡
# │ San Francisco Sheriff's Department │ San Francisco │ Black                  │              6 │
# ├────────────────────────────────────┼───────────────┼────────────────────────┼────────────────┤
# │ San Francisco Police Department    │ San Francisco │ White                  │              4 │
# ├────────────────────────────────────┼───────────────┼────────────────────────┼────────────────┤
# │ San Francisco Police Department    │ San Francisco │ Hispanic/Latino        │              2 │
# ├────────────────────────────────────┼───────────────┼────────────────────────┼────────────────┤
# │ San Francisco Police Department    │ San Francisco │ Asian/Pacific Islander │              1 │
# ╘════════════════════════════════════╧═══════════════╧════════════════════════╧════════════════╛
# ╒══════════════════════════╤══════════════╤════════╤════════════════╕
# │ Agency                   │ Metro Area   │ Race   │   TOTAL DEATHS │
# ╞══════════════════════════╪══════════════╪════════╪════════════════╡
# │ Tacoma Police Department │ Tacoma       │ White  │              3 │
# ╘══════════════════════════╧══════════════╧════════╧════════════════╛
# ╒═════════════════════════════════╤═══════════════╤═════════╤════════════════╕
# │ Agency                          │ Metro Area    │ Race    │   TOTAL DEATHS │
# ╞═════════════════════════════════╪═══════════════╪═════════╪════════════════╡
# │ St Petersburg Police Department │ St Petersburg │ White   │              3 │
# ├─────────────────────────────────┼───────────────┼─────────┼────────────────┤
# │ Tampa Police Department         │ Tampa         │ Unknown │              1 │
# ╘═════════════════════════════════╧═══════════════╧═════════╧════════════════╛
# ╒════════════════════════════════════╤══════════════╤═════════════════╤════════════════╕
# │ Agency                             │ Metro Area   │ Race            │   TOTAL DEATHS │
# ╞════════════════════════════════════╪══════════════╪═════════════════╪════════════════╡
# │ Washington County Sheriff's Office │ Wellman      │ Unknown         │              5 │
# ├────────────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ Arlington Police Department        │ Arlington    │ Black           │              4 │
# ├────────────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ Washington County Sheriff's Office │ Aloha        │ White           │              2 │
# ├────────────────────────────────────┼──────────────┼─────────────────┼────────────────┤
# │ Arlington Police Department        │ Arlington    │ Hispanic/Latino │              1 │
# ╘════════════════════════════════════╧══════════════╧═════════════════╧════════════════╛
